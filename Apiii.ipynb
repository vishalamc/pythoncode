# %%
# !pip install requests
# Out:
# ...
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# ...

# %%
# importing the requests library
import requests
r=requests.get('https://cdndemo-api.co-vin.in/api/v2/admin/location/states')
r.json()
# Out:
# {'states': [{'state_id': 1, 'state_name': 'Andaman and Nicobar Islands'},
#   {'state_id': 2, 'state_name': 'Andhra Pradesh'},
#   {'state_id': 3, 'state_name': 'Arunachal Pradesh'},
#   {'state_id': 4, 'state_name': 'Assam'},
#   {'state_id': 5, 'state_name': 'Bihar'},
#   {'state_id': 6, 'state_name': 'Chandigarh'},
#   {'state_id': 7, 'state_name': 'Chhattisgarh'},
#   {'state_id': 8, 'state_name': 'Dadar and Nagar Haveli'},
#   {'state_id': 54, 'state_name': 'Dadra and Nagar Haveli'},
#   {'state_id': 37, 'state_name': 'Daman and Diu'},
#   {'state_id': 9, 'state_name': 'Delhi'},
#   {'state_id': 80, 'state_name': 'Demo'},
#   {'state_id': 83, 'state_name': 'Demo State'},
#   {'state_id': 82, 'state_name': 'DhState1'},
#   {'state_id': 90, 'state_name': 'DNM State'},
#   {'state_id': 10, 'state_name': 'Goa'},
#   {'state_id': 11, 'state_name': 'Gujarat'},
#   {'state_id': 12, 'state_name': 'Haryana II'},
#   {'state_id': 13, 'state_name': 'Himachal Pradesh'},
# ...

# %%
# importing the requests library
import requests
import json
print_flag = 'Y'
result=requests.get('https://cdndemo-api.co-vin.in/api/v2/admin/location/states')
response_json = result.json()
flag = False
if response_json["states"]:            
    if(print_flag.lower() =='y'):
        for center in response_json["states"]:
            print(center)
# Out:
# {'state_id': 1, 'state_name': 'Andaman and Nicobar Islands'}
# {'state_id': 2, 'state_name': 'Andhra Pradesh'}
# {'state_id': 3, 'state_name': 'Arunachal Pradesh'}
# {'state_id': 4, 'state_name': 'Assam'}
# {'state_id': 5, 'state_name': 'Bihar'}
# {'state_id': 6, 'state_name': 'Chandigarh'}
# {'state_id': 7, 'state_name': 'Chhattisgarh'}
# {'state_id': 8, 'state_name': 'Dadar and Nagar Haveli'}
# {'state_id': 54, 'state_name': 'Dadra and Nagar Haveli'}
# {'state_id': 37, 'state_name': 'Daman and Diu'}
# {'state_id': 9, 'state_name': 'Delhi'}
# {'state_id': 80, 'state_name': 'Demo'}
# {'state_id': 83, 'state_name': 'Demo State'}
# {'state_id': 82, 'state_name': 'DhState1'}
# {'state_id': 90, 'state_name': 'DNM State'}
# {'state_id': 10, 'state_name': 'Goa'}
# {'state_id': 11, 'state_name': 'Gujarat'}
# {'state_id': 12, 'state_name': 'Haryana II'}
# {'state_id': 13, 'state_name': 'Himachal Pradesh'}
# {'state_id': 14, 'state_name': 'Jammu and Kashmir'}
# ...

# %%
import requests
import json
result=requests.get('https://cdndemo-api.co-vin.in/api/v2/admin/location/states')
response_json = result.json()
'''for p in response_json['states']:
        print('State Id',p['state_id'])
        print('State Name: ' + p['state_name']) 
        print('')'''
id=int(input("Enter State Id\n"))
for p in response_json['states']:
    if p['state_id']==id:
        print('State Name: ' + p['state_name'])
# Out:
# Enter State Id
# 5
# State Name: Bihar

# %%
import requests
import json
result=requests.get('https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/calendarByPin?pincode=144001&date=01-11-2021')
response_json = result.json()
for p in response_json['centers']:
        print('District:',p['district_name'])
        print('Name: ' + p['name']) 
        print('Address: '+p['address'])
        print('') 
for p in response_json['sessions']:
        print('Time:',p['date'])
# Out:
# District: Jalandhar
# Name: Military Hosp Only For Army
# Address: Mh Jalandhar Cantt
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10856/4109590733.py in <module>
#       8         print('Address: '+p['address'])
#       9         print('')
# ---> 10 for p in response_json['sessions']:
#      11         print('Time:',p['date'])
#
# KeyError: 'sessions'

# %%
import requests
import json
r=requests.get('')
r.json()
# Out:
# {'sessions': []}

# %%
# !pip install requests pygame
# Out:
# ...
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\rockstar\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.3.1 is available.
# ...

# %%
import requests
from pygame import mixer 
from datetime import datetime, timedelta
import time


age = 52
pincodes = ["144001"]
num_days = 2

print_flag = 'Y'

print("Starting search for Covid vaccine slots!")

actual = datetime.today()
list_format = [actual + timedelta(days=i) for i in range(num_days)]
actual_dates = [i.strftime("%d-%m-%Y") for i in list_format]

while True:
    counter = 0   

    for pincode in pincodes:   
        for given_date in actual_dates:

            URL = "https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/calendarByPin?pincode={}&date={}".format(pincode, given_date)
            header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'} 
            
            result = requests.get(URL, headers=header)

            if result.ok:
                response_json = result.json()
                if response_json["centers"]:
                    if(print_flag.lower() =='y'):
                        for center in response_json["centers"]:
                            for session in center["sessions"]:
                                if (session["min_age_limit"] <= age and session["available_capacity"] > 0 ) :
                                    print('Pincode: ' + pincode)
                                    print("Available on: {}".format(given_date))
                                    print("\t", center["name"])
                                    print("\t", center["block_name"])
                                    print("\t Price: ", center["fee_type"])
                                    print("\t Availablity : ", session["available_capacity"])

                                    if(session["vaccine"] != ''):
                                        print("\t Vaccine type: ", session["vaccine"])
                                    print("\n")
                                    counter = counter + 1
            else:
                print("No Response!")
                
    if counter:
        print("No Vaccination slot available!")
    else:
       
        print("Search Completed!")

    dt = datetime.now() + timedelta(minutes=3)

    while datetime.now() < dt:
        time.sleep(1)
# Out:
# Starting search for Covid vaccine slots!
# Pincode: 144001
# Available on: 31-10-2021
# 	 Military Hosp Only For Army
# 	 Jalandhar
# 	 Price:  Free
# 	 Availablity :  9
# 	 Vaccine type:  COVISHIELD
#
#
# Pincode: 144001
# Available on: 31-10-2021
# 	 Military Hosp Only For Army
# 	 Jalandhar
# 	 Price:  Free
# 	 Availablity :  15
# 	 Vaccine type:  COVAXIN
#
#
# Pincode: 144001
# Available on: 31-10-2021
# 	 Military Hosp Only For Army
# 	 Jalandhar
# 	 Price:  Free
# 	 Availablity :  15
# 	 Vaccine type:  COVISHIELD
#
#
# Pincode: 144001
# Available on: 31-10-2021
# 	 Military Hosp Only For Army
# 	 Jalandhar
# 	 Price:  Free
# 	 Availablity :  20
# 	 Vaccine type:  COVAXIN
#
#
# Pincode: 144001
# Available on: 31-10-2021
# 	 Military Hosp Only For Army
# 	 Jalandhar
# 	 Price:  Free
# 	 Availablity :  20
# 	 Vaccine type:  COVAXIN
#
#
# Pincode: 144001
# Available on: 31-10-2021
# 	 Military Hosp Only For Army
# 	 Jalandhar
# 	 Price:  Free
# 	 Availablity :  20
# ...
